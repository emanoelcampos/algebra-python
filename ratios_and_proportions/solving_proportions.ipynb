# %% [markdown]
# # Set up a proportion:
#
# n1/d1 = n2/d2

# %%
# Put a zero un for the unknown value

n1 = 1
d1 = 2
n2 = 0
d2 = 16

if n2 == 0:
  answer = d2 * n1 / d1
  print("n2 = ", answer)

n1 = 1
d1 = 2
n2 = 4
d2 = 0

if d2 == 0:
  answer = n2 * d1 / n1
  print("d2 = ", answer)
# Out:
# n2 =  8.0
# d2 =  8.0
